# %%
import requests
import numpy as np
import pandas as pd
import pandas_profiling
import json
import os
import matplotlib.pyplot as plt

pd.options.display.max_columns = None

# %%
os.chdir(r'C:\Users\2bogu\Desktop\Sringboard_Materials\capstone2\data\interim')

df = pd.read_csv('iter_avg')

# %%
df.shape
# Out:
# (27384, 27)

# %%
df.describe()
# Out:
#        ORIGINAL LOAN AMOUNT  ORIGINAL TERM  INTEREST RATE  CREDIT SCORE  \
# count          27384.000000   27384.000000   27384.000000  27384.000000
# mean           11651.353257     168.875584       3.872760    734.570552
# std             6688.382432      30.737487       1.049828     55.201293
# min               61.000000       1.000000       2.990000    479.000000
# 25%             6095.000000     180.000000       3.490000    699.000000
# 50%            10473.000000     180.000000       3.490000    745.000000
# 75%            16167.500000     180.000000       3.490000    780.000000
# max            25000.000000     180.000000       8.490000    837.000000
#
#        CREDIT SCORE NAME 2  DEBT TO INCOME  PAYMENT AMOUNT  CURRENT BALANCE  \
# count         27384.000000    27384.000000    27384.000000     27384.000000
# mean            734.780456        0.330100       91.994957      7479.811094
# std              55.979200        2.657283       53.368442      6245.144749
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27384 entries, 0 to 27383
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CONTRACT DATE             27384 non-null  object
#  1   SETUP DATE                27384 non-null  object
#  2   ORIGINAL LOAN AMOUNT      27384 non-null  float64
#  3   ORIGINAL TERM             27384 non-null  int64
#  4   ORIGINAL MATURITY DATE    27384 non-null  object
#  5   CURRENT MATURITY DATE     27384 non-null  object
#  6   INTEREST RATE             27384 non-null  float64
#  7   CREDIT SCORE              27384 non-null  float64
#  8   CREDIT SCORE NAME 2       27384 non-null  float64
#  9   DEBT TO INCOME            27384 non-null  float64
#  10  PAYMENT AMOUNT            27384 non-null  float64
#  11  CURRENT BALANCE           27384 non-null  float64
#  12  UNAPPLIED CASH            27384 non-null  float64
# ...
